# %%
import numpy as np

# %%
arr = np.array([1,2,3],dtype=np.int8)

# %%
arr[1:]
#print(arr.shape)



#print(arr.dtype)
# Out:
# array([2, 3], dtype=int8)

# %%
arr = np.array([
    [1,2,3]
    ,[4,5,6]
])
print(arr.shape)
arr
# Out:
# (2, 3)
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr[0,:]
# Out:
# array([1, 2, 3])

# %%
arr[0,1:]
# Out:
# array([2, 3])

# %%
arr[-1,1:]
# Out:
# array([5, 6])

# %%
#broadcasting
arr[0] = 12
arr
# Out:
# array([[12, 12, 12],
#        [ 4,  5,  6]])

# %%
arr[0] = [12, 13 ,14]
arr
# Out:
# array([[12, 13, 14],
#        [ 4,  5,  6]])

# %%
arr = np.array([
    [10, 20, 30, 40],
    [10, 20, 30, 40]
    ])
arr[0] = [12,13]
arr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 5
#       1 arr = np.array([
#       2     [10, 20, 30, 40],
#       3     [10, 20, 30, 40]
#       4     ])
# ----> 5 arr[0] = [12,13]
#       6 arr
#
# ValueError: could not broadcast input array from shape (2,) into shape (4,)

# %%
arr = np.array([256,257], dtype= 'int32')
arr.astype('uint8')
# Out:
# array([0, 1], dtype=uint8)

# %%
arr = np.array([
    [10, 20, 30, 40],
    [10, 20, 30, 40]
    ])

arr > 30
# Out:
# array([[False, False, False,  True],
#        [False, False, False,  True]])

# %%
arr[arr > 4] = 50
arr
# Out:
# array([[50, 50, 50, 50],
#        [50, 50, 50, 50]])

# %%
arr
# Out:
# array([[10, 20, 30, 40],
#        [10, 20, 30, 40]])

# %%
arr[
    arr > 11
    & (arr <=20)
] = 11
arr
# Out:
# array([[11, 11, 11, 11],
#        [11, 11, 11, 11]])

# %%
students = np.array(['BOB', 'Alice', 'John'])
notes = np.array([15,18,4])
students[notes >= 10]
# Out:
# array(['BOB', 'Alice'], dtype='<U5')

# %%
ar = np.array([1,2,3])
arr+1
# Out:
# array([[12, 12, 12, 12],
#        [12, 12, 12, 12]])

# %%
arr = np.array([1,2,3])
arr2 = np.array([1,1,1])
print(arr+1)
arr+arr2
# Out:
# [2 3 4]
# array([2, 3, 4])

# %%
arr.sum()

# %%
arr = np.array([1,2,np.nan])
np.nansum(arr)
# Out:
# np.float64(3.0)

# %%
#Generateur pseudo aleatoire
np.random.seed(1)
np.random.randint(0,10,size=3)
# Out:
# array([5, 8, 9], dtype=int32)

# %%
chars = np.array(['a', 'b', 'c'])
np.random.choice(chars, size = 50)
# Out:
# array(['b', 'a', 'c', 'a', 'a', 'b', 'b', 'c', 'a', 'a', 'b', 'c', 'c',
#        'b', 'a', 'c', 'b', 'c', 'b', 'a', 'b', 'b', 'c', 'a', 'a', 'c',
#        'c', 'b', 'a', 'c', 'c', 'c', 'a', 'a', 'b', 'b', 'b', 'a', 'a',
#        'b', 'b', 'c', 'a', 'b', 'c', 'c', 'a', 'b', 'b', 'a'], dtype='<U1')
